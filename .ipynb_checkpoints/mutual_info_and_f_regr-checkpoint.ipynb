# %%
import numpy as np
import pandas as pd

# %%
seed=42
np.random.seed(seed)
import os
dir_path='C:\\Data Science\\kaggle regr competion'
csv_file='preprocessedtrain.csv'
dataset=pd.read_csv(os.path.join(dir_path,csv_file))

# %%
dataset.head(10)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  \
# 0          60         65.0     8450            7            5       196.0
# 1          20         80.0     9600            6            8         0.0
# 2          60         68.0    11250            7            5       162.0
# 3          70         60.0     9550            7            5         0.0
# 4          60         84.0    14260            8            5       350.0
# 5          50         85.0    14115            5            5         0.0
# 6          20         75.0    10084            8            5       186.0
# 7          50         51.0     6120            7            5         0.0
# 8         190         50.0     7420            5            6         0.0
# 9          20         70.0    11200            5            5         0.0
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF      ...       \
# 0         706           0        150          856      ...
# ...

# %%
X=dataset.loc[:, dataset.columns != 'SalePrice']
y=dataset['SalePrice']
# Out:
# C:\Users\moisessalazar77\Anaconda3\envs\regression_competition\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   app.launch_new_instance()

# %%
from sklearn.feature_selection import f_regression, mutual_info_regression
scores=[]
for c in list(X.columns):
    f_test, _ = f_regression(X[c].reshape(-1,1), y)
    mi = mutual_info_regression(X[c].reshape(-1,1), y)
    scores.append((c,f_test,mi))
# Out:
# C:\Users\moisessalazar77\Anaconda3\envs\regression_competition\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\moisessalazar77\Anaconda3\envs\regression_competition\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\moisessalazar77\Anaconda3\envs\regression_competition\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\moisessalazar77\Anaconda3\envs\regression_competition\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# ...

# %%
scores = pd.DataFrame(scores, columns=['Variable','F_score','Mutual_info'])

# %%
f_list=scores[scores['F_score']>=201.74].Variable.tolist()

# %%
f_list
# Out:
# ['OverallQual',
#  'GarageCars',
#  'GrLivArea',
#  'AgeGarage',
#  'Age',
#  'GarageArea',
#  'TotalBsmtSF',
#  'FullBath',
#  'ExterQual_TA',
#  '1stFlrSF',
#  'ExterQual_Gd',
#  'GarageFinish_Unf',
#  'KitchenQual_TA',
#  'BsmtQual_TA',
#  'AgeRemod',
#  'Foundation_PConc',
#  'KitchenQual_Gd',
#  'Fireplaces',
#  'FireplaceQu_no_fireplace',
#  'TotRmsAbvGrd',
#  'Exterior2nd_VinylSd',
#  'BsmtFinType1_GLQ',
#  'GarageType_Detchd',
#  'BsmtFinSF1',
#  'OpenPorchSF',
#  'Exterior1st_VinylSd',
#  'MasVnrArea',
#  'MasVnrType_None',
#  'Neighborhood_NridgHt',
#  'MasVnrType_Stone']

# %%
scores.sort_values(by='Mutual_info',ascending=False).head(30)
# Out:
#                     Variable               F_score            Mutual_info
# 0                OverallQual   [2372.563425516487]   [0.5009658256216405]
# 1                 GarageCars  [1017.6267589467624]   [0.3380044602557615]
# 2                  GrLivArea  [1252.3066124544798]   [0.3373193454207559]
# 3                  AgeGarage   [473.1631598608167]   [0.3106543169378373]
# 4                        Age   [739.1231369364324]   [0.2953327963116721]
# 5                 GarageArea   [922.9814183966267]  [0.28462158465210363]
# 6                TotalBsmtSF    [812.690992347242]  [0.26794255352791385]
# 7                   FullBath   [586.0971863757142]  [0.26674420926147135]
# 8               ExterQual_TA   [828.7387280830841]  [0.25513834278870307]
# 9                   1stFlrSF   [671.4014418110281]  [0.24145976299756633]
# 10              ExterQual_Gd    [560.757520583841]  [0.23234276973753998]
# 11          GarageFinish_Unf   [632.5782124721558]  [0.23110613465419916]
# ...

# %%
mutual_info_list=scores[scores['Mutual_info']>=0.10115359].Variable.tolist()

# %%
mutual_info_list
# Out:
# ['OverallQual',
#  'GarageCars',
#  'GrLivArea',
#  'AgeGarage',
#  'Age',
#  'GarageArea',
#  'TotalBsmtSF',
#  'FullBath',
#  'ExterQual_TA',
#  '1stFlrSF',
#  'ExterQual_Gd',
#  'GarageFinish_Unf',
#  'KitchenQual_TA',
#  'LotFrontage',
#  'BsmtQual_TA',
#  'AgeRemod',
#  'Foundation_PConc',
#  'KitchenQual_Gd',
#  'BsmtQual_Gd',
#  'Fireplaces',
#  'FireplaceQu_no_fireplace',
#  'TotRmsAbvGrd',
#  'OverallCond',
#  'Exterior2nd_VinylSd',
#  'GarageFinish_RFn',
#  'BsmtFinType1_GLQ',
#  'GarageType_Detchd',
#  'BsmtFinSF1',
#  'HeatingQC_TA',
#  'Foundation_CBlock']
